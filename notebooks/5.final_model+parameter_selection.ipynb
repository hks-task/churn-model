# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import seaborn as sns

import xgboost
from sklearn import metrics
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import RandomizedSearchCV

import warnings
warnings.filterwarnings("ignore") 

kfold = KFold(n_splits=5, random_state=42)
break_point = datetime(2017, 2, 28)

# %%
def read_data():
    
    print('Reading files...')    
    order_df = pd.read_csv('../input/machine_learning_challenge_order_data.csv')
    print('Order data has {} rows and {} columns'.format(order_df.shape[0], order_df.shape[1]))
    label_df = pd.read_csv('../input/machine_learning_challenge_labeled_data.csv')
    print('Label data has {} rows and {} columns'.format(label_df.shape[0], label_df.shape[1]))
    df = order_df.merge(label_df, on='customer_id')
    print('The final data has {} rows and {} columns'.format(df.shape[0], df.shape[1]))
    return df

# %%
def reduce_mem_usage(df, verbose=False):
    
    start_mem = df.memory_usage().sum() / 1024 ** 2
    int_columns = df.select_dtypes(include=["int"]).columns
    float_columns = df.select_dtypes(include=["float"]).columns

    for col in int_columns:
        df[col] = pd.to_numeric(df[col], downcast="integer")

    for col in float_columns:
        df[col] = pd.to_numeric(df[col], downcast="float")

    end_mem = df.memory_usage().sum() / 1024 ** 2
    if verbose:
        print(
            "Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)".format(
                end_mem, 100 * (start_mem - end_mem) / start_mem
            )
        )
    return df

# %%
def getWeeklyDates(df, break_point):

    df['order_date'] = pd.to_datetime(df['order_date'])
    three_day = df[df['order_date'] >= break_point - timedelta(days=3)]
    one_week = df[df['order_date'] >= break_point - timedelta(days=7)]
    two_week = df[df['order_date'] >= break_point - timedelta(days=14)]
    four_week = df[df['order_date'] >= break_point - timedelta(days=28)]
    twelve_week = df[df['order_date'] >= break_point - timedelta(days=84)]
    twenty_four_week = df[df['order_date'] >= break_point - timedelta(days=168)]
    all_week = df
    return three_day, one_week, two_week, four_week, twelve_week, twenty_four_week,all_week

# %%
def transform_data(df):

    labelencoder = LabelEncoder()

    for i in ['restaurant_id', 'city_id', 'payment_id', 'platform_id', 'transmission_id']:
        df[i] = labelencoder.fit_transform(df[i])

    return df

# %%
def feature_engineering(df, break_point):
    
    df['customer_order_rank'] = df['customer_order_rank'].fillna(method='ffill')

    df['date'] = pd.to_datetime(df['order_date']) 
    df['recency'] = (break_point - df['date']) / np.timedelta64(1, 'D')
    df['first_order_date'] = df.groupby(['customer_id'])['date'].transform('first')
    df['age_of_user'] = (break_point - df['first_order_date']) / np.timedelta64(1, 'D')

    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    df['week'] = df['date'].dt.week
    df['day'] = df['date'].dt.day
    df['dayofweek'] = df['date'].dt.dayofweek
    df["is_weekend"] = df["dayofweek"].isin([5, 6]).astype(np.int8)
    
    df['demand'] = 1
    
    df['order_date_shift'] = df.groupby('customer_id')['date'].shift()
    df['date_diff'] = (df['date'] - df['order_date_shift']) / np.timedelta64(1, 'D')

    three_day, one_week, two_week, four_week, twelve_week, twenty_four_week,all_week = getWeeklyDates(df, break_point)
    
    col = ['demand', 'is_failed','voucher_amount','delivery_fee', 'amount_paid', 'date_diff']
    three_day, one_week, two_week, four_week, twelve_week, twenty_four_week,all_week = getWeeklyDates(df, break_point)
    three_day = three_day.groupby('customer_id')[col].mean().add_prefix('three_day_').reset_index()
    one_week = one_week.groupby('customer_id')[col].mean().add_prefix('one_week_').reset_index()
    two_week = two_week.groupby('customer_id')[col].mean().add_prefix('two_week_').reset_index()
    four_week = four_week.groupby('customer_id')[col].mean().add_prefix('four_week_').reset_index()
    twelve_week = twelve_week.groupby('customer_id')[col].mean().add_prefix('twelve_week_').reset_index()
    twenty_four_week = twenty_four_week.groupby('customer_id')[col].mean().add_prefix('twenty_four_week_').reset_index()
    all_week = all_week.groupby('customer_id')[col].mean().add_prefix('all_week_').reset_index()
    
    df = df.groupby('customer_id').last().reset_index()
    df = df.merge(three_day, how='left').merge(one_week, how='left').merge(two_week, how='left').merge(four_week,
    'left').merge(twelve_week,'left').merge(twenty_four_week,'left').merge(all_week,'left').reset_index()

    return df

# %%
def run_xgb(df):
    
    y = df['is_returning_customer']
    X = df.drop(columns=['customer_id', 'order_date', 'date', 'is_returning_customer',
                        'first_order_date', 'index', 'order_date_shift'])    
    
    clf_xgb = xgboost.XGBClassifier(objective = 'binary:logistic', scale_pos_weight=2)
    param_dist = {
              'max_depth': np.arange(3,15,3) ,
              'min_child_weight': np.arange(1,8,1),
                      'colsample_bytree': np.arange(0.3,0.9,0.1),
              'n_estimators': np.arange(100,1000,100),
        'learning_rate'    : np.arange(0.05,0.3,0.05)
        
             }
    
    fit_params={"early_stopping_rounds":10,
               "eval_metric" : "auc", 
            "eval_set" : [[X, y]]}

    grid_search = RandomizedSearchCV(clf_xgb, 
                         param_distributions = param_dist,
                         #cv = kfold,  
                         n_iter = 100,
                         error_score = 0, 
                         verbose = 3, 
                         n_jobs = -1,
                         fit_params=fit_params,)
    
    grid_result = grid_search.fit(X,y)

    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    means = grid_result.cv_results_[ 'mean_test_score' ]
    stds = grid_result.cv_results_[ 'std_test_score' ]
    params = grid_result.cv_results_[ 'params' ]
    print(means, stds, params)
    
    print('Accuracy Score:  ', round(metrics.accuracy_score(y, y_pred), 2))
    print('Roc Auc Score:  ', round(roc_auc_score(y, y_pred), 2))
    print('Classification Report: \n', classification_report(y, y_pred, target_names=['0', '1']))
    return predicted

# %%
def transform_train_and_eval():
    
    df = read_data()
    df = reduce_mem_usage(df, True)
    df = transform_data(df)
    df = feature_engineering(df, break_point)
    predicted = run_xgb(df)
    return predicted

predicted = transform_train_and_eval()
# Out:
# Reading files...
# Order data has 786600 rows and 13 columns
# Label data has 245455 rows and 2 columns
# Mem. usage decreased to 42.76 Mb (52.5% reduction)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/model_selection/_search.py:643: DeprecationWarning: "fit_params" as a constructor argument was deprecated in version 0.19 and will be removed in version 0.21. Pass fit parameters to the "fit" method instead.
#   '"fit" method instead.', DeprecationWarning)
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed: 11.5min
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed: 114.1min
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /Users/kaan.simsek/anaconda3/envs/forecasting/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed: 308.6min
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed: 365.1min finished
# [0]	validation_0-auc:0.815414
# Will train until validation_0-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.834612
# [2]	validation_0-auc:0.838115
# [3]	validation_0-auc:0.837227
# [4]	validation_0-auc:0.841533
# [5]	validation_0-auc:0.843863
# [6]	validation_0-auc:0.844772
# [7]	validation_0-auc:0.846449
# [8]	validation_0-auc:0.847587
# [9]	validation_0-auc:0.84879
# [10]	validation_0-auc:0.849284
# [11]	validation_0-auc:0.849706
# [12]	validation_0-auc:0.850416
# [13]	validation_0-auc:0.850496
# [14]	validation_0-auc:0.851395
# [15]	validation_0-auc:0.852587
# [16]	validation_0-auc:0.853205
# [17]	validation_0-auc:0.854107
# [18]	validation_0-auc:0.854934
# [19]	validation_0-auc:0.855826
# [20]	validation_0-auc:0.856726
# [21]	validation_0-auc:0.857221
# [22]	validation_0-auc:0.857558
# [23]	validation_0-auc:0.857869
# [24]	validation_0-auc:0.858275
# [25]	validation_0-auc:0.858979
# [26]	validation_0-auc:0.859724
# [27]	validation_0-auc:0.860447
# [28]	validation_0-auc:0.861055
# [29]	validation_0-auc:0.86141
# [30]	validation_0-auc:0.862394
# [31]	validation_0-auc:0.863289
# [32]	validation_0-auc:0.863796
# [33]	validation_0-auc:0.864625
# [34]	validation_0-auc:0.865238
# [35]	validation_0-auc:0.866148
# [36]	validation_0-auc:0.866621
# [37]	validation_0-auc:0.8672
# [38]	validation_0-auc:0.867725
# [39]	validation_0-auc:0.867999
# [40]	validation_0-auc:0.868621
# [41]	validation_0-auc:0.86881
# [42]	validation_0-auc:0.86931
# [43]	validation_0-auc:0.869796
# [44]	validation_0-auc:0.87023
# [45]	validation_0-auc:0.870869
# [46]	validation_0-auc:0.871416
# [47]	validation_0-auc:0.871809
# [48]	validation_0-auc:0.872273
# [49]	validation_0-auc:0.872386
# [50]	validation_0-auc:0.873071
# [51]	validation_0-auc:0.873854
# [52]	validation_0-auc:0.874322
# [53]	validation_0-auc:0.87456
# [54]	validation_0-auc:0.874858
# [55]	validation_0-auc:0.875716
# [56]	validation_0-auc:0.876281
# [57]	validation_0-auc:0.877313
# [58]	validation_0-auc:0.877735
# [59]	validation_0-auc:0.878157
# [60]	validation_0-auc:0.87885
# [61]	validation_0-auc:0.879471
# [62]	validation_0-auc:0.879906
# [63]	validation_0-auc:0.880272
# [64]	validation_0-auc:0.880746
# [65]	validation_0-auc:0.881472
# [66]	validation_0-auc:0.882105
# [67]	validation_0-auc:0.882877
# [68]	validation_0-auc:0.882901
# [69]	validation_0-auc:0.883271
# [70]	validation_0-auc:0.883984
# [71]	validation_0-auc:0.884399
# [72]	validation_0-auc:0.884791
# [73]	validation_0-auc:0.885365
# [74]	validation_0-auc:0.885744
# [75]	validation_0-auc:0.886067
# [76]	validation_0-auc:0.886504
# [77]	validation_0-auc:0.886985
# [78]	validation_0-auc:0.887456
# [79]	validation_0-auc:0.887958
# [80]	validation_0-auc:0.888257
# [81]	validation_0-auc:0.888515
# [82]	validation_0-auc:0.888886
# [83]	validation_0-auc:0.889057
# [84]	validation_0-auc:0.88991
# [85]	validation_0-auc:0.890033
# [86]	validation_0-auc:0.890257
# [87]	validation_0-auc:0.890373
# [88]	validation_0-auc:0.89069
# [89]	validation_0-auc:0.89087
# [90]	validation_0-auc:0.891339
# [91]	validation_0-auc:0.891637
# [92]	validation_0-auc:0.891785
# [93]	validation_0-auc:0.8923
# [94]	validation_0-auc:0.892654
# [95]	validation_0-auc:0.892869
# [96]	validation_0-auc:0.89304
# [97]	validation_0-auc:0.893833
# [98]	validation_0-auc:0.894227
# [99]	validation_0-auc:0.894652
# [100]	validation_0-auc:0.894908
# [101]	validation_0-auc:0.895265
# [102]	validation_0-auc:0.895454
# [103]	validation_0-auc:0.895664
# [104]	validation_0-auc:0.895948
# [105]	validation_0-auc:0.896042
# [106]	validation_0-auc:0.896336
# [107]	validation_0-auc:0.896593
# [108]	validation_0-auc:0.896903
# [109]	validation_0-auc:0.897218
# [110]	validation_0-auc:0.897305
# [111]	validation_0-auc:0.897498
# [112]	validation_0-auc:0.897651
# [113]	validation_0-auc:0.897856
# [114]	validation_0-auc:0.897985
# [115]	validation_0-auc:0.89814
# [116]	validation_0-auc:0.898227
# [117]	validation_0-auc:0.898405
# [118]	validation_0-auc:0.898652
# [119]	validation_0-auc:0.898823
# [120]	validation_0-auc:0.898965
# [121]	validation_0-auc:0.899071
# [122]	validation_0-auc:0.899255
# [123]	validation_0-auc:0.899546
# [124]	validation_0-auc:0.899621
# [125]	validation_0-auc:0.89973
# [126]	validation_0-auc:0.899807
# [127]	validation_0-auc:0.900146
# [128]	validation_0-auc:0.900279
# [129]	validation_0-auc:0.900455
# [130]	validation_0-auc:0.90056
# [131]	validation_0-auc:0.900627
# [132]	validation_0-auc:0.900777
# [133]	validation_0-auc:0.900874
# [134]	validation_0-auc:0.901132
# [135]	validation_0-auc:0.901207
# [136]	validation_0-auc:0.901249
# [137]	validation_0-auc:0.901394
# [138]	validation_0-auc:0.901507
# [139]	validation_0-auc:0.9017
# [140]	validation_0-auc:0.901909
# [141]	validation_0-auc:0.901972
# [142]	validation_0-auc:0.902248
# [143]	validation_0-auc:0.902564
# [144]	validation_0-auc:0.902646
# [145]	validation_0-auc:0.902725
# [146]	validation_0-auc:0.902801
# [147]	validation_0-auc:0.903078
# [148]	validation_0-auc:0.903227
# [149]	validation_0-auc:0.903435
# [150]	validation_0-auc:0.903486
# [151]	validation_0-auc:0.90362
# [152]	validation_0-auc:0.903664
# [153]	validation_0-auc:0.903887
# [154]	validation_0-auc:0.903982
# [155]	validation_0-auc:0.904173
# [156]	validation_0-auc:0.90426
# [157]	validation_0-auc:0.904381
# [158]	validation_0-auc:0.904573
# [159]	validation_0-auc:0.904605
# [160]	validation_0-auc:0.904717
# [161]	validation_0-auc:0.904739
# [162]	validation_0-auc:0.904802
# [163]	validation_0-auc:0.904835
# [164]	validation_0-auc:0.904961
# [165]	validation_0-auc:0.904969
# [166]	validation_0-auc:0.905016
# [167]	validation_0-auc:0.905143
# [168]	validation_0-auc:0.905206
# [169]	validation_0-auc:0.905276
# [170]	validation_0-auc:0.905493
# [171]	validation_0-auc:0.90562
# [172]	validation_0-auc:0.905787
# [173]	validation_0-auc:0.906112
# [174]	validation_0-auc:0.906168
# [175]	validation_0-auc:0.906196
# [176]	validation_0-auc:0.906218
# [177]	validation_0-auc:0.906299
# [178]	validation_0-auc:0.90638
# [179]	validation_0-auc:0.906473
# [180]	validation_0-auc:0.906505
# [181]	validation_0-auc:0.90677
# [182]	validation_0-auc:0.906845
# [183]	validation_0-auc:0.906852
# [184]	validation_0-auc:0.906979
# [185]	validation_0-auc:0.907263
# [186]	validation_0-auc:0.907288
# [187]	validation_0-auc:0.907302
# [188]	validation_0-auc:0.907497
# [189]	validation_0-auc:0.907554
# [190]	validation_0-auc:0.907673
# [191]	validation_0-auc:0.907685
# [192]	validation_0-auc:0.908032
# [193]	validation_0-auc:0.908038
# [194]	validation_0-auc:0.908069
# [195]	validation_0-auc:0.9082
# [196]	validation_0-auc:0.908264
# [197]	validation_0-auc:0.90828
# [198]	validation_0-auc:0.908292
# [199]	validation_0-auc:0.908317
# [200]	validation_0-auc:0.908351
# [201]	validation_0-auc:0.908429
# [202]	validation_0-auc:0.908677
# [203]	validation_0-auc:0.909001
# [204]	validation_0-auc:0.909056
# [205]	validation_0-auc:0.90944
# [206]	validation_0-auc:0.909686
# [207]	validation_0-auc:0.909759
# [208]	validation_0-auc:0.909799
# [209]	validation_0-auc:0.909866
# [210]	validation_0-auc:0.909927
# [211]	validation_0-auc:0.910053
# [212]	validation_0-auc:0.910284
# [213]	validation_0-auc:0.910446
# [214]	validation_0-auc:0.910542
# [215]	validation_0-auc:0.910616
# [216]	validation_0-auc:0.910627
# [217]	validation_0-auc:0.910855
# [218]	validation_0-auc:0.910869
# [219]	validation_0-auc:0.910874
# [220]	validation_0-auc:0.910906
# [221]	validation_0-auc:0.910966
# [222]	validation_0-auc:0.911284
# [223]	validation_0-auc:0.911344
# [224]	validation_0-auc:0.911459
# [225]	validation_0-auc:0.911468
# [226]	validation_0-auc:0.911484
# [227]	validation_0-auc:0.911542
# [228]	validation_0-auc:0.911582
# [229]	validation_0-auc:0.911618
# [230]	validation_0-auc:0.911671
# [231]	validation_0-auc:0.911743
# [232]	validation_0-auc:0.912168
# [233]	validation_0-auc:0.912458
# [234]	validation_0-auc:0.912511
# [235]	validation_0-auc:0.912536
# [236]	validation_0-auc:0.912773
# [237]	validation_0-auc:0.913015
# [238]	validation_0-auc:0.913055
# [239]	validation_0-auc:0.913155
# [240]	validation_0-auc:0.913205
# [241]	validation_0-auc:0.913254
# [242]	validation_0-auc:0.913438
# [243]	validation_0-auc:0.913466
# [244]	validation_0-auc:0.913893
# [245]	validation_0-auc:0.913906
# [246]	validation_0-auc:0.914025
# [247]	validation_0-auc:0.914097
# [248]	validation_0-auc:0.914316
# [249]	validation_0-auc:0.914361
# [250]	validation_0-auc:0.914786
# [251]	validation_0-auc:0.914912
# [252]	validation_0-auc:0.914995
# [253]	validation_0-auc:0.915272
# [254]	validation_0-auc:0.915364
# [255]	validation_0-auc:0.915405
# [256]	validation_0-auc:0.915542
# [257]	validation_0-auc:0.915675
# [258]	validation_0-auc:0.915717
# [259]	validation_0-auc:0.915817
# [260]	validation_0-auc:0.915852
# [261]	validation_0-auc:0.915859
# [262]	validation_0-auc:0.916141
# [263]	validation_0-auc:0.91616
# [264]	validation_0-auc:0.916218
# [265]	validation_0-auc:0.916238
# [266]	validation_0-auc:0.916359
# [267]	validation_0-auc:0.916402
# [268]	validation_0-auc:0.916411
# [269]	validation_0-auc:0.916472
# [270]	validation_0-auc:0.916666
# [271]	validation_0-auc:0.916828
# [272]	validation_0-auc:0.916832
# [273]	validation_0-auc:0.916969
# [274]	validation_0-auc:0.917024
# [275]	validation_0-auc:0.917136
# [276]	validation_0-auc:0.917149
# [277]	validation_0-auc:0.917164
# [278]	validation_0-auc:0.917169
# [279]	validation_0-auc:0.917467
# [280]	validation_0-auc:0.917477
# [281]	validation_0-auc:0.917485
# [282]	validation_0-auc:0.917497
# [283]	validation_0-auc:0.917559
# [284]	validation_0-auc:0.917637
# [285]	validation_0-auc:0.917874
# [286]	validation_0-auc:0.917877
# [287]	validation_0-auc:0.918084
# [288]	validation_0-auc:0.918564
# [289]	validation_0-auc:0.918673
# [290]	validation_0-auc:0.918754
# [291]	validation_0-auc:0.918772
# [292]	validation_0-auc:0.919265
# [293]	validation_0-auc:0.919287
# [294]	validation_0-auc:0.919472
# [295]	validation_0-auc:0.919528
# [296]	validation_0-auc:0.919576
# [297]	validation_0-auc:0.919594
# [298]	validation_0-auc:0.919633
# [299]	validation_0-auc:0.919854
# [300]	validation_0-auc:0.919871
# [301]	validation_0-auc:0.919937
# [302]	validation_0-auc:0.919997
# [303]	validation_0-auc:0.920029
# [304]	validation_0-auc:0.920045
# [305]	validation_0-auc:0.920124
# [306]	validation_0-auc:0.92021
# [307]	validation_0-auc:0.920237
# [308]	validation_0-auc:0.920388
# [309]	validation_0-auc:0.920453
# [310]	validation_0-auc:0.920498
# [311]	validation_0-auc:0.920512
# [312]	validation_0-auc:0.920534
# [313]	validation_0-auc:0.920558
# [314]	validation_0-auc:0.920727
# [315]	validation_0-auc:0.920882
# [316]	validation_0-auc:0.920943
# [317]	validation_0-auc:0.92097
# [318]	validation_0-auc:0.921007
# [319]	validation_0-auc:0.921285
# [320]	validation_0-auc:0.921322
# [321]	validation_0-auc:0.921329
# [322]	validation_0-auc:0.921337
# [323]	validation_0-auc:0.92148
# [324]	validation_0-auc:0.921557
# [325]	validation_0-auc:0.921831
# [326]	validation_0-auc:0.922166
# [327]	validation_0-auc:0.922186
# [328]	validation_0-auc:0.92222
# [329]	validation_0-auc:0.922245
# [330]	validation_0-auc:0.922266
# [331]	validation_0-auc:0.922288
# [332]	validation_0-auc:0.922521
# [333]	validation_0-auc:0.92257
# [334]	validation_0-auc:0.922604
# [335]	validation_0-auc:0.922654
# [336]	validation_0-auc:0.922952
# [337]	validation_0-auc:0.92316
# [338]	validation_0-auc:0.923175
# [339]	validation_0-auc:0.923457
# [340]	validation_0-auc:0.923479
# [341]	validation_0-auc:0.923484
# [342]	validation_0-auc:0.923571
# [343]	validation_0-auc:0.923665
# [344]	validation_0-auc:0.924109
# [345]	validation_0-auc:0.924271
# [346]	validation_0-auc:0.924289
# [347]	validation_0-auc:0.924337
# [348]	validation_0-auc:0.924471
# [349]	validation_0-auc:0.924494
# [350]	validation_0-auc:0.924823
# [351]	validation_0-auc:0.924864
# [352]	validation_0-auc:0.924922
# [353]	validation_0-auc:0.925005
# [354]	validation_0-auc:0.925068
# [355]	validation_0-auc:0.92517
# [356]	validation_0-auc:0.925407
# [357]	validation_0-auc:0.925788
# [358]	validation_0-auc:0.925878
# [359]	validation_0-auc:0.926068
# [360]	validation_0-auc:0.926206
# [361]	validation_0-auc:0.926243
# [362]	validation_0-auc:0.926506
# [363]	validation_0-auc:0.926525
# [364]	validation_0-auc:0.926554
# [365]	validation_0-auc:0.926815
# [366]	validation_0-auc:0.927015
# [367]	validation_0-auc:0.927131
# [368]	validation_0-auc:0.927347
# [369]	validation_0-auc:0.92745
# [370]	validation_0-auc:0.92748
# [371]	validation_0-auc:0.927501
# [372]	validation_0-auc:0.927632
# [373]	validation_0-auc:0.927959
# [374]	validation_0-auc:0.927974
# [375]	validation_0-auc:0.928025
# [376]	validation_0-auc:0.928035
# [377]	validation_0-auc:0.928241
# [378]	validation_0-auc:0.928259
# [379]	validation_0-auc:0.928391
# [380]	validation_0-auc:0.928411
# [381]	validation_0-auc:0.928516
# [382]	validation_0-auc:0.928569
# [383]	validation_0-auc:0.928597
# [384]	validation_0-auc:0.928617
# [385]	validation_0-auc:0.928675
# [386]	validation_0-auc:0.928779
# [387]	validation_0-auc:0.928845
# [388]	validation_0-auc:0.928881
# [389]	validation_0-auc:0.928891
# [390]	validation_0-auc:0.928948
# [391]	validation_0-auc:0.928962
# [392]	validation_0-auc:0.929017
# [393]	validation_0-auc:0.929066
# [394]	validation_0-auc:0.929184
# [395]	validation_0-auc:0.929324
# [396]	validation_0-auc:0.929645
# [397]	validation_0-auc:0.929657
# [398]	validation_0-auc:0.929837
# [399]	validation_0-auc:0.929849
# [400]	validation_0-auc:0.929851
# [401]	validation_0-auc:0.929862
# [402]	validation_0-auc:0.930098
# [403]	validation_0-auc:0.930102
# [404]	validation_0-auc:0.930113
# [405]	validation_0-auc:0.930195
# [406]	validation_0-auc:0.930223
# [407]	validation_0-auc:0.930245
# [408]	validation_0-auc:0.930269
# [409]	validation_0-auc:0.93031
# [410]	validation_0-auc:0.930315
# [411]	validation_0-auc:0.930396
# [412]	validation_0-auc:0.93046
# [413]	validation_0-auc:0.930464
# [414]	validation_0-auc:0.930472
# [415]	validation_0-auc:0.930535
# [416]	validation_0-auc:0.930705
# [417]	validation_0-auc:0.930754
# [418]	validation_0-auc:0.93085
# [419]	validation_0-auc:0.930978
# [420]	validation_0-auc:0.931105
# [421]	validation_0-auc:0.931139
# [422]	validation_0-auc:0.931272
# [423]	validation_0-auc:0.931385
# [424]	validation_0-auc:0.931413
# [425]	validation_0-auc:0.931418
# [426]	validation_0-auc:0.931461
# [427]	validation_0-auc:0.931714
# [428]	validation_0-auc:0.931943
# [429]	validation_0-auc:0.931993
# [430]	validation_0-auc:0.931998
# [431]	validation_0-auc:0.932119
# [432]	validation_0-auc:0.93219
# [433]	validation_0-auc:0.932199
# [434]	validation_0-auc:0.932269
# [435]	validation_0-auc:0.932277
# [436]	validation_0-auc:0.932303
# [437]	validation_0-auc:0.932315
# [438]	validation_0-auc:0.932366
# [439]	validation_0-auc:0.932401
# [440]	validation_0-auc:0.932404
# [441]	validation_0-auc:0.932465
# [442]	validation_0-auc:0.932503
# [443]	validation_0-auc:0.932507
# [444]	validation_0-auc:0.933058
# [445]	validation_0-auc:0.933065
# [446]	validation_0-auc:0.933177
# [447]	validation_0-auc:0.933232
# [448]	validation_0-auc:0.933245
# [449]	validation_0-auc:0.933312
# [450]	validation_0-auc:0.933533
# [451]	validation_0-auc:0.933617
# [452]	validation_0-auc:0.933636
# [453]	validation_0-auc:0.933652
# [454]	validation_0-auc:0.933755
# [455]	validation_0-auc:0.933767
# [456]	validation_0-auc:0.933787
# [457]	validation_0-auc:0.933822
# [458]	validation_0-auc:0.933911
# [459]	validation_0-auc:0.934004
# [460]	validation_0-auc:0.934036
# [461]	validation_0-auc:0.934151
# [462]	validation_0-auc:0.934272
# [463]	validation_0-auc:0.934337
# [464]	validation_0-auc:0.934534
# [465]	validation_0-auc:0.934651
# [466]	validation_0-auc:0.934713
# [467]	validation_0-auc:0.935062
# [468]	validation_0-auc:0.935225
# [469]	validation_0-auc:0.935313
# [470]	validation_0-auc:0.935379
# [471]	validation_0-auc:0.935548
# [472]	validation_0-auc:0.935656
# [473]	validation_0-auc:0.935693
# [474]	validation_0-auc:0.935955
# [475]	validation_0-auc:0.936006
# [476]	validation_0-auc:0.936241
# [477]	validation_0-auc:0.936263
# [478]	validation_0-auc:0.936343
# [479]	validation_0-auc:0.936617
# [480]	validation_0-auc:0.937188
# [481]	validation_0-auc:0.93721
# [482]	validation_0-auc:0.93732
# [483]	validation_0-auc:0.937327
# [484]	validation_0-auc:0.937398
# [485]	validation_0-auc:0.937454
# [486]	validation_0-auc:0.937698
# [487]	validation_0-auc:0.938158
# [488]	validation_0-auc:0.938501
# [489]	validation_0-auc:0.938508
# [490]	validation_0-auc:0.93851
# [491]	validation_0-auc:0.938575
# [492]	validation_0-auc:0.93865
# [493]	validation_0-auc:0.938741
# [494]	validation_0-auc:0.938759
# [495]	validation_0-auc:0.93877
# [496]	validation_0-auc:0.938832
# [497]	validation_0-auc:0.939145
# [498]	validation_0-auc:0.939185
# [499]	validation_0-auc:0.939262
# [500]	validation_0-auc:0.939319
# [501]	validation_0-auc:0.93934
# [502]	validation_0-auc:0.93939
# [503]	validation_0-auc:0.939411
# [504]	validation_0-auc:0.939422
# [505]	validation_0-auc:0.939505
# [506]	validation_0-auc:0.939599
# [507]	validation_0-auc:0.939647
# [508]	validation_0-auc:0.93972
# [509]	validation_0-auc:0.939773
# [510]	validation_0-auc:0.939841
# [511]	validation_0-auc:0.939872
# [512]	validation_0-auc:0.939886
# [513]	validation_0-auc:0.939953
# [514]	validation_0-auc:0.940057
# [515]	validation_0-auc:0.940059
# [516]	validation_0-auc:0.940172
# [517]	validation_0-auc:0.940224
# [518]	validation_0-auc:0.940241
# [519]	validation_0-auc:0.940252
# [520]	validation_0-auc:0.940273
# [521]	validation_0-auc:0.940413
# [522]	validation_0-auc:0.940426
# [523]	validation_0-auc:0.940442
# [524]	validation_0-auc:0.940466
# [525]	validation_0-auc:0.940473
# [526]	validation_0-auc:0.94049
# [527]	validation_0-auc:0.940509
# [528]	validation_0-auc:0.940511
# [529]	validation_0-auc:0.940592
# [530]	validation_0-auc:0.940717
# [531]	validation_0-auc:0.940725
# [532]	validation_0-auc:0.940826
# [533]	validation_0-auc:0.940979
# [534]	validation_0-auc:0.94102
# [535]	validation_0-auc:0.941088
# [536]	validation_0-auc:0.941377
# [537]	validation_0-auc:0.94151
# [538]	validation_0-auc:0.941622
# [539]	validation_0-auc:0.941656
# [540]	validation_0-auc:0.941742
# [541]	validation_0-auc:0.941813
# [542]	validation_0-auc:0.941906
# [543]	validation_0-auc:0.942047
# [544]	validation_0-auc:0.942135
# [545]	validation_0-auc:0.942281
# [546]	validation_0-auc:0.942289
# [547]	validation_0-auc:0.94238
# [548]	validation_0-auc:0.942448
# [549]	validation_0-auc:0.942574
# [550]	validation_0-auc:0.942578
# [551]	validation_0-auc:0.942634
# [552]	validation_0-auc:0.942798
# [553]	validation_0-auc:0.943021
# [554]	validation_0-auc:0.943024
# [555]	validation_0-auc:0.943079
# [556]	validation_0-auc:0.943284
# [557]	validation_0-auc:0.943332
# [558]	validation_0-auc:0.943387
# [559]	validation_0-auc:0.943545
# [560]	validation_0-auc:0.943628
# [561]	validation_0-auc:0.943689
# [562]	validation_0-auc:0.943692
# [563]	validation_0-auc:0.943752
# [564]	validation_0-auc:0.943823
# [565]	validation_0-auc:0.943909
# [566]	validation_0-auc:0.944057
# [567]	validation_0-auc:0.944101
# [568]	validation_0-auc:0.944217
# [569]	validation_0-auc:0.944434
# [570]	validation_0-auc:0.944447
# [571]	validation_0-auc:0.944526
# [572]	validation_0-auc:0.944756
# [573]	validation_0-auc:0.944785
# [574]	validation_0-auc:0.944815
# [575]	validation_0-auc:0.944847
# [576]	validation_0-auc:0.944906
# [577]	validation_0-auc:0.944954
# [578]	validation_0-auc:0.94499
# [579]	validation_0-auc:0.944994
# [580]	validation_0-auc:0.945044
# [581]	validation_0-auc:0.945176
# [582]	validation_0-auc:0.945254
# [583]	validation_0-auc:0.945347
# [584]	validation_0-auc:0.94538
# [585]	validation_0-auc:0.945402
# [586]	validation_0-auc:0.945534
# [587]	validation_0-auc:0.945551
# [588]	validation_0-auc:0.94556
# [589]	validation_0-auc:0.94578
# [590]	validation_0-auc:0.94606
# [591]	validation_0-auc:0.946093
# [592]	validation_0-auc:0.946185
# [593]	validation_0-auc:0.946257
# [594]	validation_0-auc:0.946336
# [595]	validation_0-auc:0.946397
# [596]	validation_0-auc:0.946403
# [597]	validation_0-auc:0.946416
# [598]	validation_0-auc:0.94642
# [599]	validation_0-auc:0.946443
# [600]	validation_0-auc:0.94655
# [601]	validation_0-auc:0.946605
# [602]	validation_0-auc:0.946941
# [603]	validation_0-auc:0.947141
# [604]	validation_0-auc:0.947196
# [605]	validation_0-auc:0.947295
# [606]	validation_0-auc:0.947379
# [607]	validation_0-auc:0.94738
# [608]	validation_0-auc:0.947421
# [609]	validation_0-auc:0.947501
# [610]	validation_0-auc:0.947531
# [611]	validation_0-auc:0.947566
# [612]	validation_0-auc:0.947593
# [613]	validation_0-auc:0.947923
# [614]	validation_0-auc:0.947987
# [615]	validation_0-auc:0.9482
# [616]	validation_0-auc:0.94823
# [617]	validation_0-auc:0.948314
# [618]	validation_0-auc:0.948332
# [619]	validation_0-auc:0.948339
# [620]	validation_0-auc:0.948453
# [621]	validation_0-auc:0.94848
# [622]	validation_0-auc:0.948497
# [623]	validation_0-auc:0.948503
# [624]	validation_0-auc:0.948758
# [625]	validation_0-auc:0.949111
# [626]	validation_0-auc:0.949124
# [627]	validation_0-auc:0.949167
# [628]	validation_0-auc:0.949296
# [629]	validation_0-auc:0.949328
# [630]	validation_0-auc:0.949378
# [631]	validation_0-auc:0.949384
# [632]	validation_0-auc:0.949389
# [633]	validation_0-auc:0.949396
# [634]	validation_0-auc:0.949477
# [635]	validation_0-auc:0.949478
# [636]	validation_0-auc:0.949486
# [637]	validation_0-auc:0.949678
# [638]	validation_0-auc:0.949733
# [639]	validation_0-auc:0.949744
# [640]	validation_0-auc:0.949827
# [641]	validation_0-auc:0.949843
# [642]	validation_0-auc:0.949872
# [643]	validation_0-auc:0.949978
# [644]	validation_0-auc:0.95002
# [645]	validation_0-auc:0.95004
# [646]	validation_0-auc:0.950079
# [647]	validation_0-auc:0.950138
# [648]	validation_0-auc:0.950486
# [649]	validation_0-auc:0.950547
# [650]	validation_0-auc:0.950548
# [651]	validation_0-auc:0.950714
# [652]	validation_0-auc:0.950774
# [653]	validation_0-auc:0.950854
# [654]	validation_0-auc:0.950893
# [655]	validation_0-auc:0.950958
# [656]	validation_0-auc:0.950981
# [657]	validation_0-auc:0.950984
# [658]	validation_0-auc:0.950998
# [659]	validation_0-auc:0.951032
# [660]	validation_0-auc:0.95104
# [661]	validation_0-auc:0.951119
# [662]	validation_0-auc:0.95119
# [663]	validation_0-auc:0.951224
# [664]	validation_0-auc:0.951234
# [665]	validation_0-auc:0.951484
# [666]	validation_0-auc:0.951518
# [667]	validation_0-auc:0.951631
# [668]	validation_0-auc:0.951633
# [669]	validation_0-auc:0.951643
# [670]	validation_0-auc:0.951679
# [671]	validation_0-auc:0.951734
# [672]	validation_0-auc:0.951851
# [673]	validation_0-auc:0.951899
# [674]	validation_0-auc:0.951974
# [675]	validation_0-auc:0.952271
# [676]	validation_0-auc:0.95235
# [677]	validation_0-auc:0.952358
# [678]	validation_0-auc:0.952542
# [679]	validation_0-auc:0.952762
# [680]	validation_0-auc:0.952877
# [681]	validation_0-auc:0.952887
# [682]	validation_0-auc:0.952998
# [683]	validation_0-auc:0.953043
# [684]	validation_0-auc:0.953071
# [685]	validation_0-auc:0.953096
# [686]	validation_0-auc:0.953125
# [687]	validation_0-auc:0.953153
# [688]	validation_0-auc:0.953173
# [689]	validation_0-auc:0.953179
# [690]	validation_0-auc:0.95332
# [691]	validation_0-auc:0.953337
# [692]	validation_0-auc:0.953378
# [693]	validation_0-auc:0.95364
# [694]	validation_0-auc:0.953771
# [695]	validation_0-auc:0.953785
# [696]	validation_0-auc:0.95379
# [697]	validation_0-auc:0.953817
# [698]	validation_0-auc:0.953873
# [699]	validation_0-auc:0.953911
# Best: 0.829879 using {'n_estimators': 700, 'min_child_weight': 1, 'max_depth': 12, 'learning_rate': 0.05, 'colsample_bytree': 0.4}
# [0.82465218 0.82573995 0.82391477 0.82722291 0.82334848 0.8298792
#  0.82756513 0.82507995 0.82560958 0.82339736 0.8256218  0.8232507
#  0.82578884 0.82089589 0.82278625 0.82461551 0.82666477 0.82611477
#  0.82643254 0.82620847 0.8254018  0.8273655  0.818647   0.82384551
#  0.82545477 0.82567884 0.82542625 0.82556069 0.82547514 0.82367847
#  0.82518995 0.82644884 0.82336477 0.82141737 0.82457477 0.82484773
#  0.82477032 0.82177181 0.82563403 0.82384144 0.82638365 0.82672995
#  0.82526329 0.8224807  0.82522662 0.82849402 0.82565847 0.82364181
#  0.82304292 0.8236581  0.82376403 0.82379255 0.8269581  0.82224033
#  0.82886476 0.82386588 0.82443625 0.82539773 0.82009737 0.82166181
#  0.82157218 0.82936995 0.8256381  0.82726365 0.8257318  0.82567884
#  0.82554847 0.82163329 0.82490884 0.82509625 0.82788699 0.82477032
#  0.82496588 0.82578884 0.82713736 0.8224644  0.82554032 0.82491292
#  0.82797254 0.8275855  0.82515329 0.82321811 0.8253244  0.8250881
#  0.82104255 0.82515736 0.82089181 0.81894848 0.82489662 0.82160477
#  0.82275366 0.82104255 0.82601699 0.82173107 0.81861441 0.82529995
#  0.82544662 0.82741847 0.82681551 0.82692551] [0.00112695 0.00172651 0.00187824 0.00170764 0.00191645 0.00156847
#  0.00136797 0.0021483  0.00111201 0.00137647 0.00079502 0.00224511
#  0.0014003  0.00256658 0.00156325 0.00216691 0.0019986  0.00147619
#  0.00124132 0.0014943  0.0016813  0.00130461 0.0005056  0.00130233
#  0.00147428 0.00136938 0.00130704 0.00186258 0.00170278 0.00265822
#  0.00139312 0.00154402 0.0018287  0.00206905 0.00184736 0.00167185
#  0.00167609 0.00174931 0.00130084 0.00124937 0.00174041 0.00196545
#  0.00142343 0.00260213 0.00128438 0.00181637 0.00170536 0.0018439
#  0.00161323 0.00207066 0.0023353  0.00198019 0.00195739 0.00180549
#  0.00148132 0.00182134 0.00191324 0.00178989 0.00132298 0.00187205
#  0.00171748 0.00142945 0.00211085 0.00081591 0.00176645 0.00127907
#  0.00151927 0.00253763 0.00152132 0.00199285 0.00203433 0.00201564
#  0.00164461 0.00171841 0.00139368 0.00135293 0.00200142 0.00224721
#  0.0018842  0.00145044 0.00230525 0.00248699 0.00139958 0.00141144
#  0.00247767 0.00153453 0.00200102 0.00110258 0.00182652 0.00123337
#  0.00225757 0.00181195 0.00118103 0.00114912 0.00138378 0.00163436
#  0.00099943 0.00162534 0.00147233 0.00191947] [{'n_estimators': 100, 'min_child_weight': 2, 'max_depth': 3, 'learning_rate': 0.15000000000000002, 'colsample_bytree': 0.3}, {'n_estimators': 400, 'min_child_weight': 2, 'max_depth': 12, 'learning_rate': 0.15000000000000002, 'colsample_bytree': 0.3}, {'n_estimators': 900, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.15000000000000002, 'colsample_bytree': 0.4}, {'n_estimators': 400, 'min_child_weight': 2, 'max_depth': 9, 'learning_rate': 0.05, 'colsample_bytree': 0.5}, {'n_estimators': 600, 'min_child_weight': 6, 'max_depth': 9, 'learning_rate': 0.15000000000000002, 'colsample_bytree': 0.7000000000000002}, {'n_estimators': 700, 'min_child_weight': 1, 'max_depth': 12, 'learning_rate': 0.05, 'colsample_bytree': 0.4}, {'n_estimators': 300, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.05, 'colsample_bytree': 0.3}, {'n_estimators': 400, 'min_child_weight': 4, 'max_depth': 6, 'learning_rate': 0.15000000000000002, 'colsample_bytree': 0.8000000000000003}, {'n_estimators': 500, 'min_child_weight': 6, 'max_depth': 3, 'learning_rate': 0.05, 'colsample_bytree': 0.6000000000000001}, {'n_estimators': 900, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.2, 'colsample_bytree': 0.6000000000000001}, {'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.15000000000000002, 'colsample_bytree': 0.4}, {'n_estimators': 800, 'min_child_weight': 7, 'max_depth': 9, 'learning_rate': 0.15000000000000002, 'colsample_bytree': 0.7000000000000002}, {'n_estimators': 300, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1, 'colsample_bytree': 0.6000000000000001}, {'n_estimators': 400, 'min_child_weight': 5, 'max_depth': 9, 'learning_rate': 0.25, 'colsample_bytree': 0.5}, {'n_estimators': 400, 'min_child_weight': 4, 'max_depth': 12, 'learning_rate': 0.2, 'colsample_bytree': 0.5}, {'n_estimators': 600, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.15000000000000002, 'colsample_bytree': 0.7000000000000002}, {'n_estimators': 300, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.05, 'colsample_bytree': 0.9000000000000001}, {'n_estimators': 600, 'min_child_weight': 6, 'max_depth': 6, 'learning_rate': 0.05, 'colsample_bytree': 0.5}, {'n_estimators': 400, 'min_child_weight': 5, 'max_depth': 6, 'learning_rate': 0.05, 'colsample_bytree': 0.7000000000000002}, {'n_estimators': 300, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.05, 'colsample_bytree': 0.8000000000000003}, {'n_estimators': 800, 'min_child_weight': 7, 'max_depth': 3, 'learning_rate': 0.1, 'colsample_bytree': 0.9000000000000001}, {'n_estimators': 300, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.05, 'colsample_bytree': 0.3}, {'n_estimators': 900, 'min_child_weight': 5, 'max_depth': 9, 'learning_rate': 0.25, 'colsample_bytree': 0.3}, {'n_estimators': 400, 'min_child_weight': 2, 'max_depth': 12, 'learning_rate': 0.2, 'colsample_bytree': 0.9000000000000001}, {'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 3, 'learning_rate': 0.1, 'colsample_bytree': 0.6000000000000001}, {'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2, 'colsample_bytree': 0.6000000000000001}, {'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 6, 'learning_rate': 0.2, 'colsample_bytree': 0.6000000000000001}, {'n_estimators': 500, 'min_child_weight': 4, 'max_depth': 6, 'learning_rate': 0.1, 'colsample_bytree': 0.6000000000000001}, {'n_estimators': 400, 'min_child_weight': 2, 'max_depth': 9, 'learning_rate': 0.15000000000000002, 'colsample_bytree': 0.3}, {'n_estimators': 500, 'min_child_weight': 3, 'max_depth': 6, 'learning_rate': 0.2, 'colsample_bytree': 0.7000000000000002}, {'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 3, 'learning_rate': 0.1, 'colsample_bytree': 0.3}, {'n_estimators': 900, 'min_child_weight': 6, 'max_depth': 6, 'learning_rate': 0.05, 'colsample_bytree': 0.3}, {'n_estimators': 800, 'min_child_weight': 7, 'max_ ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-219634982a75> in <module>
#       8     return predicted
#       9
# ---> 10 predicted = transform_train_and_eval()
#
# <ipython-input-61-219634982a75> in transform_train_and_eval()
#       5     df = transform_data(df)
#       6     df = feature_engineering(df, break_point)
# ----> 7     predicted = run_xgb(df)
#       8     return predicted
#       9
#
# <ipython-input-60-356d2cd38ec5> in run_xgb(df)
#      36     print(means, stds, params)
#      37
# ---> 38     print('Accuracy Score:  ', round(metrics.accuracy_score(y, y_pred), 2))
#      39     print('Roc Auc Score:  ', round(roc_auc_score(y, y_pred), 2))
#      40     print('Classification Report: \n', classification_report(y, y_pred, target_names=['0', '1']))
#
# NameError: name 'y_pred' is not defined
